# %%
import bw2data as bd
import bw2calc as bc
import pbaesa
from pbaesa import utilities as u
# Out:
# 18:00:56+0200 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %%
bd.projects.set_current('pbaesatest') # Set the current Brightway25 project where you want to apply pbaesa
bio = bd.Database("ecoinvent-3.10.1-biosphere")
ei = bd.Database("ecoinvent-3.10.1-cutoff")

# %%
pbaesa.create_pbaesa_methods(bio)
# Out:
# N-supply elementary flows already exists in biosphere!
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from calcium ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from monoammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from diammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from monoammonium phosphate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from manure, liquid, swine. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from potassium nitrate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from compost. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (15-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from potassium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from potassium nitrate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from ash, from combustion of straw. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate phosphate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from vinasse, from fermentation of sweet sorghum. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea ammonium nitrate mix. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea ammonium nitrate mix. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from fermentation filtrate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from coconut husk. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (26-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium sulfate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from diammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from potassium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from calcium ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea ammonium nitrate mix. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (26-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium chloride. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from calcium nitrate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from filter cake, from sugarcane juice filtration. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from manure, liquid, cattle. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from monoammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (26-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from diammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from diammonium phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from monoammonium phosphate. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from manure, solid, cattle. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (15-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium sulfate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from calcium ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from calcium ammonium nitrate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (15-15-15) fertiliser. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonium nitrate phosphate. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (15-15-15) fertiliser. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from poultry manure, dried. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from vinasse, from fermentation of sugar beet molasses. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from urea ammonium nitrate mix. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from vinasse, from fermentation of sugar beet. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from poultry manure, fresh. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from ammonia, anhydrous, liquid. Exchanges: 1
# N-flow added to organic nitrogen fertiliser, as N - nutrient supply from vinasse, from fermentation of sugarcane. Exchanges: 1
# N-flow added to inorganic nitrogen fertiliser, as N - nutrient supply from NPK (26-15-15) fertiliser. Exchanges: 1
# The following planetary boundary categories are now available as LCIA-methods:
# - ('Planetary Boundaries', 'Nitrogen Cycle')
# The following planetary boundary categories are now available as LCIA-methods:
# - ('Planetary Boundaries', 'Nitrogen Cycle')
# - ('Planetary Boundaries', 'Climate Change')
# - ('Planetary Boundaries', 'Ocean Acidification')
# - ('Planetary Boundaries', 'Change in Biosphere Integrity')
# - ('Planetary Boundaries', 'Phosphorus Cycle')
# - ('Planetary Boundaries', 'Atmospheric Aerosol Loading')
# - ('Planetary Boundaries', 'Freshwater Use')
# - ('Planetary Boundaries', 'Stratospheric Ozone Depletion')
# - ('Planetary Boundaries', 'Land-system Change')
# All Planetary-Boundary-LCIA methods are successfully implemented in your project!

# %%
m = [met for met in bd.methods if "Planetary Boundaries" in str(met)]
m
# Out:
# [('Planetary Boundaries', 'Nitrogen Cycle'),
#  ('Planetary Boundaries', 'Climate Change'),
#  ('Planetary Boundaries', 'Ocean Acidification'),
#  ('Planetary Boundaries', 'Change in Biosphere Integrity'),
#  ('Planetary Boundaries', 'Phosphorus Cycle'),
#  ('Planetary Boundaries', 'Atmospheric Aerosol Loading'),
#  ('Planetary Boundaries', 'Freshwater Use'),
#  ('Planetary Boundaries', 'Stratospheric Ozone Depletion'),
#  ('Planetary Boundaries', 'Land-system Change')]

# %%
my_process = ei.get(name='wheat grain production', location='DE')

fu = 22.6 * 10e6

functional_unit = {
    "wheat production": {my_process.id: fu },
}
config = {
    "impact_categories": m,
}
data_objs = bd.get_multilca_data_objs(
    functional_units=functional_unit, method_config=config
)

mlca = bc.MultiLCA(demands=functional_unit, method_config=config, data_objs=data_objs)
mlca.lci()
mlca.lcia()
mlca_scores = mlca.scores

# %%
exploitations = u.calculate_exploitation_of_SOS(mlca_scores)
exploitations
# Out:
# {(('Planetary Boundaries', 'Nitrogen Cycle'),
#   'wheat production'): 8.375034739994082e-05,
#  (('Planetary Boundaries', 'Climate Change'),
#   'wheat production'): 1.9588687834172194e-05,
#  (('Planetary Boundaries', 'Ocean Acidification'),
#   'wheat production'): 4.532930188957121e-06,
#  (('Planetary Boundaries', 'Change in Biosphere Integrity'),
#   'wheat production'): 2.5427623049501263e-05,
#  (('Planetary Boundaries', 'Phosphorus Cycle'),
#   'wheat production'): 2.0891978166970844e-06,
#  (('Planetary Boundaries', 'Atmospheric Aerosol Loading'),
#   'wheat production'): 3.830335011550619e-06,
#  (('Planetary Boundaries', 'Freshwater Use'),
#   'wheat production'): 4.826557644308421e-06,
#  (('Planetary Boundaries', 'Stratospheric Ozone Depletion'),
#   'wheat production'): 1.2153900569207879e-06,
#  (('Planetary Boundaries', 'Land-system Change'),
#   'wheat production'): 4.0275415747462e-06}

# %%
mlca_scores
# Out:
# {(('Planetary Boundaries', 'Nitrogen Cycle'),
#   'wheat production'): 0.005192521538796331,
#  (('Planetary Boundaries', 'Climate Change'),
#   'wheat production'): 1.9588687834172194e-05,
#  (('Planetary Boundaries', 'Ocean Acidification'),
#   'wheat production'): 3.118655970002499e-06,
#  (('Planetary Boundaries', 'Change in Biosphere Integrity'),
#   'wheat production'): 0.0002542762304950126,
#  (('Planetary Boundaries', 'Phosphorus Cycle'),
#   'wheat production'): 2.0891978166970844e-05,
#  (('Planetary Boundaries', 'Atmospheric Aerosol Loading'),
#   'wheat production'): 4.2133685127056816e-07,
#  (('Planetary Boundaries', 'Freshwater Use'),
#   'wheat production'): 0.019306230577233685,
#  (('Planetary Boundaries', 'Stratospheric Ozone Depletion'),
#   'wheat production'): 1.7623155825351426e-05,
#  (('Planetary Boundaries', 'Land-system Change'),
#   'wheat production'): 0.00034274378801090155}

# %%
u.plot_AESA(exploitations, 0.000012, 0.00002)

# %%
pbaesa.get_all_allocation_factor("DE", "Cultivation of wheat", 2022)
# Out:
# Allocation factors file for year 2022 not found.
# Attempting to generate allocation factors...
# Final Consumption Expenditure per geographical scope calculated!
# Final Consumption Expenditure per sector within geographical scope calculated!
# Final Consumption Expenditure per geographical scope calculated!
# Final Consumption Expenditure per sector within geographical scope calculated!
#                    Unnamed: 0  \
# 1654  DE_Cultivation of wheat
#
#       Allocation factor calculated via total final consumption expenditure  \
# 1654                                           0.000066
#
#       Allocation factor calculated via direct final consumption expenditure  \
# 1654                                           0.000026
#
#       Allocation factor calculated via total gross value added  \
# 1654                                           0.000025
#
#       Allocation factor calculated via direct gross value added  \
# 1654                                           0.000013
#
#      Country (c.f. ISO 3166-1 alpha-2) & Rest of World regions  \
# 1654                                                 DE
#
#      Sector (c.f. EU’s NACE Rev.1 classification)
# 1654                         Cultivation of wheat
